# %%
import yfinance as yf
from datetime import datetime

# %%
start_date = "2025-01-01"
end_date   = "2025-01-31"

# %%
ticker="^GSPC"

# %%
df_single = yf.download(
    tickers=ticker,
    start=start_date,
    end=end_date,
    interval="1d",
    group_by="ticker",
    auto_adjust=True,
    progress=False
)

# %%
df_single
# Out:
# Ticker            ^GSPC
# Price              Open         High          Low        Close      Volume
# Date
# 2025-01-02  5903.259766  5935.089844  5829.529785  5868.549805  3621680000
# 2025-01-03  5891.069824  5949.339844  5888.660156  5942.470215  3667340000
# 2025-01-06  5982.810059  6021.040039  5960.009766  5975.379883  4940120000
# 2025-01-07  5993.259766  6000.680176  5890.680176  5909.029785  4517330000
# 2025-01-08  5910.660156  5927.890137  5874.779785  5918.250000  4441740000
# 2025-01-10  5890.350098  5890.350098  5807.779785  5827.040039  4751930000
# 2025-01-13  5782.020020  5838.609863  5773.310059  5836.220215  4421200000
# 2025-01-14  5859.270020  5871.919922  5805.419922  5842.910156  4142280000
# 2025-01-15  5905.209961  5960.609863  5905.209961  5949.910156  4544570000
# 2025-01-16  5963.609863  5964.689941  5930.720215  5937.339844  4285810000
# 2025-01-17  5995.399902  6014.959961  5978.439941  5996.660156  4366830000
# ...
